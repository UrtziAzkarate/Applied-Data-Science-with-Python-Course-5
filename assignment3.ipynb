# %% [markdown]
# # Assignment 3
#
# In this assignment you will explore measures of centrality on two networks, a friendship network in Part 1, and a blog network in Part 2.

# %% [markdown]
# ## Part 1
#
# Answer questions 1-4 using the network `G1`, a network of friendships at a university department. Each node corresponds to a person, and an edge indicates friendship.
#
# *The network has been loaded as networkx graph object `G1`.*

# %%
import networkx as nx

G1 = nx.read_gml('assets/friendships.gml')

# %% [markdown]
# ### Question 1
#
# Find the degree centrality, closeness centrality, and betweeness centrality of node 100.
#
# *This function should return a tuple of floats `(degree_centrality, closeness_centrality, betweenness_centrality)`.*

# %%
def answer_one():
    
    degree_c = nx.degree_centrality(G1)[100]
    closeness_c = nx.closeness_centrality(G1)[100]
    betweenness_c = nx.betweenness_centrality(G1)[100]

    return (degree_c, closeness_c, betweenness_c)

answer_one()
# Out:
# (0.0026501766784452294, 0.2654784240150094, 7.142902633244772e-05)

# %%
ans_one = answer_one()
assert type(ans_one) == tuple, "You must return a tuple"

# %% [markdown]
# ### Use centrality measures to answer questions 2-4

# %% [markdown]
# ### Question 2
#
# Suppose you are employed by an online shopping website and are tasked with selecting one user in network G1 to send an online shopping voucher to. We expect that the user who receives the voucher will send it to their friends in the network.  You want the voucher to reach as many nodes as possible. The voucher can be forwarded to multiple users at the same time, but the travel distance of the voucher is limited to one step, which means if the voucher travels more than one step in this network, it is no longer valid. Apply your knowledge in network centrality to select the best candidate for the voucher.
#
# *This function should return an integer, the chosen node.*

# %%
nx.closeness_centrality?
# Out:
# Signature: nx.closeness_centrality(G, u=None, distance=None, wf_improved=True)
# Docstring:
# Compute closeness centrality for nodes.
#
# Closeness centrality [1]_ of a node `u` is the reciprocal of the
# average shortest path distance to `u` over all `n-1` reachable nodes.
#
# .. math::
#
#     C(u) = \frac{n - 1}{\sum_{v=1}^{n-1} d(v, u)},
#
# where `d(v, u)` is the shortest-path distance between `v` and `u`,
# and `n-1` is the number of nodes reachable from `u`. Notice that the
# closeness distance function computes the incoming distance to `u`
# for directed graphs. To use outward distance, act on `G.reverse()`.
#
# Notice that higher values of closeness indicate higher centrality.
#
# Wasserman and Faust propose an improved formula for graphs with
# more than one connected component. The result is "a ratio of the
# fraction of actors in the group who are reachable, to the average
# distance" from the reachable actors [2]_. You might think this
# scale factor is inverted but it is not. As is, nodes from small
# components receive a smaller closeness value. Letting `N` denote
# the number of nodes in the graph,
#
# .. math::
#
#     C_{WF}(u) = \frac{n-1}{N-1} \frac{n - 1}{\sum_{v=1}^{n-1} d(v, u)},
#
# Parameters
# ----------
# G : graph
#   A NetworkX graph
#
# u : node, optional
#   Return only the value for node u
#
# distance : edge attribute key, optional (default=None)
#   Use the specified edge attribute as the edge distance in shortest
#   path calculations.  If `None` (the default) all edges have a distance of 1.
#   Absent edge attributes are assigned a distance of 1. Note that no check
#   is performed to ensure that edges have the provided attribute.
#
# wf_improved : bool, optional (default=True)
#   If True, scale by the fraction of nodes reachable. This gives the
#   Wasserman and Faust improved formula. For single component graphs
#   it is the same as the original formula.
#
# Returns
# -------
# nodes : dictionary
#   Dictionary of nodes with closeness centrality as the value.
#
# Examples
# --------
# >>> G = nx.Graph([(0, 1), (0, 2), (0, 3), (1, 2), (1, 3)])
# >>> nx.closeness_centrality(G)
# {0: 1.0, 1: 1.0, 2: 0.75, 3: 0.75}
#
# See Also
# --------
# betweenness_centrality, load_centrality, eigenvector_centrality,
# degree_centrality, incremental_closeness_centrality
#
# Notes
# -----
# The closeness centrality is normalized to `(n-1)/(|G|-1)` where
# `n` is the number of nodes in the connected part of graph
# containing the node.  If the graph is not completely connected,
# this algorithm computes the closeness centrality for each
# connected part separately scaled by that parts size.
#
# If the 'distance' keyword is set to an edge attribute key then the
# shortest-path length will be computed using Dijkstra's algorithm with
# that edge attribute as the edge weight.
#
# The closeness centrality uses *inward* distance to a node, not outward.
# If you want to use outword distances apply the function to `G.reverse()`
#
# In NetworkX 2.2 and earlier a bug caused Dijkstra's algorithm to use the
# outward distance rather than the inward distance. If you use a 'distance'
# keyword and a DiGraph, your results will change between v2.2 and v2.3.
#
# References
# ----------
# .. [1] Linton C. Freeman: Centrality in networks: I.
#    Conceptual clarification. Social Networks 1:215-239, 1979.
#    https://doi.org/10.1016/0378-8733(78)90021-7
# .. [2] pg. 201 of Wasserman, S. and Faust, K.,
#    Social Network Analysis: Methods and Applications, 1994,
#    Cambridge University Press.
# File:      /opt/conda/lib/python3.9/site-packages/networkx/algorithms/centrality/closeness.py
# Type:      function

# %%
def answer_two():
    
    degree_c = nx.degree_centrality(G1)
    max_degree_c = max(degree_c, key=lambda x: degree_c[x])
    
    return max_degree_c

answer_two()
# Out:
# 105

# %%
ans_two = answer_two()

# %% [markdown]
# ### Question 3
#
# Now the limit of the voucher’s travel distance has been removed. Because the network is connected, regardless of who you pick, every node in the network will eventually receive the voucher. However, we now want to ensure that the voucher reaches nodes as quickly as possible (i.e. in the fewest number of hops). How will you change your selection strategy? Write a function to tell us who is the best candidate in the network under this condition.
#
# *This function should return an integer, the chosen node.*

# %%
def answer_three():
    
    closeness_c = nx.closeness_centrality(G1)
    max_closeness_c = max(closeness_c, key=lambda x: closeness_c[x])
    
    return max_closeness_c

answer_three()
# Out:
# 23

# %%
ans_three = answer_three()

# %% [markdown]
# ### Question 4
#
# Assume the restriction on the voucher’s travel distance is still removed, but now a competitor has developed a strategy to remove a person from the network in order to disrupt the distribution of your company’s voucher. You competitor plans to remove people who act as bridges in the network. Identify the best possible person to be removed by your competitor?
#
# *This function should return an integer, the chosen node.*

# %%
def answer_four():
    
    betweenness_c = nx.betweenness_centrality(G1)
    max_betweenness_c = max(betweenness_c, key=lambda x: betweenness_c[x])
    
    return max_betweenness_c

answer_four()
# Out:
# 333

# %%
ans_four = answer_four()

# %%
import matplotlib.pyplot as plt


#node_color = [G1.degree(v) for v in G1]
node_size = [nx.betweenness_centrality(G1)[v] for v in G1]

pos = nx.spring_layout(G1)
nx.draw_networkx(G1, pos, node_size=node_size, width=0.2, font_size=2, cmap=plt.cm.Blues)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [41], line 7
#       3 plt.figure(figsize=(10,8))
#       6 #node_color = [G1.degree(v) for v in G1]
# ----> 7 node_size = [nx.betweenness_centrality(G1)[v] for v in G1]
#       9 pos = nx.spring_layout(G1)
#      10 nx.draw_networkx(G1, pos, node_size=node_size, width=0.2, font_size=2, cmap=plt.cm.Blues)
#
# Cell In [41], line 7, in <listcomp>(.0)
#       3 plt.figure(figsize=(10,8))
#       6 #node_color = [G1.degree(v) for v in G1]
# ----> 7 node_size = [nx.betweenness_centrality(G1)[v] for v in G1]
#       9 pos = nx.spring_layout(G1)
#      10 nx.draw_networkx(G1, pos, node_size=node_size, width=0.2, font_size=2, cmap=plt.cm.Blues)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 9:4, in argmap_betweenness_centrality_6(G, k, normalized, weight, endpoints, seed)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File /opt/conda/lib/python3.9/site-packages/networkx/algorithms/centrality/betweenness.py:130, in betweenness_centrality(G, k, normalized, weight, endpoints, seed)
#     127 for s in nodes:
#     128     # single source shortest paths
#     129     if weight is None:  # use BFS
# --> 130         S, P, sigma, _ = _single_source_shortest_path_basic(G, s)
#     131     else:  # use Dijkstra's algorithm
#     132         S, P, sigma, _ = _single_source_dijkstra_path_basic(G, s, weight)
#
# File /opt/conda/lib/python3.9/site-packages/networkx/algorithms/centrality/betweenness.py:277, in _single_source_shortest_path_basic(G, s)
#     275         if D[w] == Dv + 1:  # this is a shortest path, count paths
#     276             sigma[w] += sigmav
# --> 277             P[w].append(v)  # predecessors
#     278 return S, P, sigma, D
#
# KeyboardInterrupt:

# %% [markdown]
# ## Part 2
#
# `G2` is a directed network of political blogs, where nodes correspond to a blog and edges correspond to links between blogs. Use your knowledge of PageRank and HITS to answer Questions 5-9.

# %%
G2 = nx.read_gml('assets/blogs.gml')

# %% [markdown]
# ### Question 5
#
# Apply the Scaled Page Rank Algorithm to this network. Find the Page Rank of node 'realclearpolitics.com' with damping value 0.85.
#
# *This function should return a float.*

# %%
def answer_five():
    
    return nx.pagerank(G2, alpha=0.85)['realclearpolitics.com']
    
answer_five()
# Out:
# 0.004636694781649098

# %%
ans_five = answer_five()

# %% [markdown]
# ### Question 6
#
# Apply the Scaled Page Rank Algorithm to this network with damping value 0.85. Find the 5 nodes with highest Page Rank.
#
# *This function should return a list of the top 5 blogs in desending order of Page Rank.*

# %%
nx.pagerank(G2, alpha=0.85)
# Out:
# {'tsrightdominion.blogspot.com': 0.0003478782612386359,
#  'rightrainbow.com': 0.0004286700876475778,
#  'gregpalast.com': 0.002149383652281393,
#  'younglibs.com': 0.00021555645931858387,
#  'blotts.org/polilog': 0.00018740248208077342,
#  'marylandpolitics.blogspot.com': 0.00018740248208077342,
#  'blogitics.com': 0.0002449721617548766,
#  'thesakeofargument.com': 0.0002989949277473624,
#  'joebrent.blogspot.com': 0.00018740248208077342,
#  'thesiliconmind.blogspot.com': 0.00018740248208077342,
#  'kippsblog.com': 0.00018740248208077342,
#  'progressivetrail.org/blog.shtml': 0.00018740248208077342,
#  'randomjottings.net': 0.00043947432143907157,
#  'outsidethebeltway.com': 0.00395657237021411,
#  'annatopia.com/home.html': 0.0011326385953333736,
#  'politicalmonitor.us/blog': 0.00018740248208077342,
#  'suburbanguerrilla.blogspot.com': 0.001565716581790574,
#  'patterico.com': 0.001493292633163559,
#  'mayflowerhill.blogspot.com': 0.0002035884490770087,
#  'danieldrezner.com/blog': 0.0024448626998139797,
#  'brilliantatbreakfast.blogspot.com': 0.00036696368424199866,
#  'niagarabuzz.com': 0.00018740248208077342,
#  'lancehaun.com': 0.00018740248208077342,
#  'scrawlville.com': 0.00037047647522213964,
#  'home.earthlink.net/~heavy-duty': 0.00018740248208077342,
#  'mahablog.com': 0.0007761832906054639,
#  'legendgames.net/myblog.asp': 0.0010185737927519132,
#  'nationalreview.com/thecorner/corner.asp': 0.00018740248208077342,
#  'hellskitchennyc.blogspot.com': 0.00018740248208077342,
#  'alamodispatches.blogspot.com': 0.00018740248208077342,
#  'nephandus.com/blog.php': 0.00018740248208077342,
#  'ccs178.com': 0.0002447914002960239,
#  'stan-istan.blogspot.com': 0.0002290240053174766,
#  'thespoonsexperience.com': 0.0012803580663914942,
#  'progressivesociety.com/blog': 0.00020161153034276464,
#  'ibe.blogspot.com': 0.0010838901015185287,
#  'redstatealliance.blogspot.com': 0.00023818321988878388,
#  'revone.net/jarhead': 0.00018740248208077342,
#  'michaelphillips.blogspot.com': 0.0003771007904859839,
#  'nielsenhayden.com/electrolite': 0.0018521064333483102,
#  'planetsuz.blogspot.com': 0.00018740248208077342,
#  'regimechangeiran.com': 0.0003639183065201671,
#  'imprescindibile.ilcannocchiale.it': 0.0002405195535296321,
#  'godubya.com': 0.00022856023280364715,
#  'politicalpie.modblog.com': 0.00018740248208077342,
#  'nearouterheaven.blogspot.com': 0.000196880080571657,
#  'sgtstryker.com': 0.0011792129594491911,
#  'blindmindseye.com': 0.00031199564294417904,
#  'crookedtimber.org': 0.003796317448227955,
#  'vondollens.us': 0.00018740248208077342,
#  'uberddue.blogspot.com': 0.00018740248208077342,
#  'swingleft.blogspot.com': 0.00018740248208077342,
#  'markarkleiman.com': 0.0026141020870434836,
#  'therightwingconspiracy.org': 0.0003531417741990106,
#  'savetheus.blogspot.com': 0.00018740248208077342,
#  'soonerthought.com': 0.00018740248208077342,
#  'hotflashesfromthecampaigntrail.blogspot.com': 0.00019163183389580955,
#  'blogforamerica.com': 0.0023666859519234223,
#  'bowles2004.com/weblog': 0.0001932513279400187,
#  'philoponia.blogspot.com': 0.00018740248208077342,
#  'dartblog.com': 0.000585882499360284,
#  'smarthomeschool.com': 0.0002290240053174766,
#  'diplomadic.blogspot.com': 0.0010175497284943833,
#  'theimmoralminority.blogspot.com': 0.00018740248208077342,
#  'warriorscreed.000k3.com': 0.0002290240053174766,
#  'johnmccrory.com': 0.0002307351190726137,
#  'charleypatton.blogspot.com': 0.0001974475727209362,
#  'thinkingrocks.blogspot.com': 0.00020038860326046358,
#  'politicalhyperbole.blogspot.com': 0.00018740248208077342,
#  'tseytlin.blogspot.com': 0.00018740248208077342,
#  'home.earthlink.net/~goodnoughp/index.html': 0.00018740248208077342,
#  'confederateyankee.blogspot.com': 0.0010208707325271172,
#  'tagorda.com': 0.0010366051689446004,
#  'stevecopy.blogharbor.com': 0.000568322454817175,
#  'freakinliberals.com/blog_a': 0.00018740248208077342,
#  'bushlies.net/pages/10/index.htm': 0.00018740248208077342,
#  'carpetblogger.com': 0.00018740248208077342,
#  'americandigest.org': 0.0021494063215701186,
#  'someonetakethewheel.blogspot.com': 0.00018740248208077342,
#  'njn-blogogram.blogspot.com': 0.00018740248208077342,
#  'brianhull.net': 0.00018740248208077342,
#  'fraterslibertas.com': 0.0017371668231466425,
#  'pattymurray.com/blog.php': 0.00018740248208077342,
#  'electablog.com': 0.0007020594698744897,
#  'presidentboxer.blogspot.com': 0.0006055214084487781,
#  'deanesmay.com': 0.0026188057146062224,
#  'jimgilliam.com': 0.00020981707976489797,
#  'thatgoodnight.com': 0.00024328629265192966,
#  'thirdredeye.blogspot.com': 0.00018740248208077342,
#  'steveguy.me.uk': 0.00018740248208077342,
#  'undercaffeinated.com': 0.00021810631825240655,
#  'dgci.net': 0.0006312712246819611,
#  'blogsagainsthillary.com': 0.001645517176712645,
#  'xanga.com/allegrad': 0.00018740248208077342,
#  'southernwatch.blogspot.com': 0.00029090161673339286,
#  'forewarned.blogspot.com': 0.00018740248208077342,
#  'truthliesandcommonsense.blogspot.com': 0.00033974270736929083,
#  'kerrytalkingpoints.blogspot.com': 0.00018740248208077342,
#  'electionprojection.com': 0.0011234589092703714,
#  'spreadingunderstanding.blogspot.com': 0.00027580963289679987,
#  'jquinton.com': 0.0011737969352426114,
#  'randz.net': 0.00018740248208077342,
#  'kcdems.blogspot.com': 0.0002588770670486903,
#  'gloomanddoom.blogspot.com': 0.00018740248208077342,
#  'hereswhatsleft.typepad.com': 0.0002709254474972339,
#  'livejournal.com/users/hoptkov': 0.00018740248208077342,
#  'vocis.com/frank': 0.00018740248208077342,
#  'pandagon.net': 0.004231616519533316,
#  'homepage.mac.com/georgia.nesmith/iblog/index.html': 0.00018740248208077342,
#  'pollsterseek.blogspot.com': 0.00018740248208077342,
#  'lt-smash.us': 0.0012879963413472096,
#  'williamwebbdotorg.blogspot.com': 0.00036379575924305936,
#  'heathenfolk.warblogs.com/blog': 0.00018740248208077342,
#  'arkansastonight.com': 0.00024405922372470435,
#  'civicactions.com': 0.00018740248208077342,
#  'stagefour.typepad.com/commonprejudice': 0.00020388564752607944,
#  'robschumacher.blogspot.com': 0.0002508991558535176,
#  'mwilliams.info': 0.0006121573281508318,
#  'elevendayempire.com/movabletype': 0.00030330016513833036,
#  'seetheforest.blogspot.com': 0.002268844538644472,
#  'dneiwert.blogspot.com': 0.002808049469570614,
#  'philosophers-stone.blogspot.com': 0.000196880080571657,
#  'rightwingjournal.blogspot.com': 0.00021429401922536513,
#  'x-pollen.com/many/blog.html': 0.00018740248208077342,
#  'hellafaded.blogspot.com': 0.00020854528715466293,
#  'drudgereport.com': 0.010712415519898426,
#  'sulliwatch.blogspot.com': 0.00018740248208077342,
#  'browncross.com/usualsuspects': 0.00019789772539278929,
#  'markmeador.blogspot.com': 0.00018740248208077342,
#  'luxeword.com': 0.00042881414041889837,
#  'sadlyno.com': 0.0011043462081193147,
#  'tuibguy.messagemonster.com': 0.00018740248208077342,
#  'zebrax.blogs.com': 0.0002550044398066609,
#  'rockpaperscissors.blogs.com': 0.00018740248208077342,
#  'motgs.com': 0.0002703121927741779,
#  'writehouse.us': 0.00018740248208077342,
#  'thedumbdemocrat.blogspot.com': 0.00018740248208077342,
#  'americanreport.blogspot.com': 0.00020173783081336983,
#  'onetrueblog.com': 0.00018740248208077342,
#  'alexpelan.blogspot.com': 0.0002290240053174766,
#  'alamonation.blogspot.com': 0.00030903353970836687,
#  'blubberhollow.com/blog': 0.0002511795616350627,
#  'ivotedforgeorge.com': 0.00028823081142631844,
#  ...}

# %%
def answer_six():
    
    p_rank = nx.pagerank(G2, alpha=0.85)
    
    sorted_p_rank = sorted(p_rank.items(), key=lambda x: x[1], reverse=True)[0:5]
    
    top5 = list(zip(*sorted_p_rank))[0]
    
    return list(top5)

answer_six()
# Out:
# ('dailykos.com',
#  'atrios.blogspot.com',
#  'instapundit.com',
#  'blogsforbush.com',
#  'talkingpointsmemo.com')

# %%
ans_six = answer_six()
assert type(ans_six) == list, "You must return a list"

# %% [markdown]
# ### Question 7
#
# Apply the HITS Algorithm to the network to find the hub and authority scores of node 'realclearpolitics.com'.
#
# *Your result should return a tuple of floats `(hub_score, authority_score)`.*

# %%
def answer_seven():
    
    hub = nx.hits(G2)[0]['realclearpolitics.com']
    authority = nx.hits(G2)[1]['realclearpolitics.com']
    
    return (hub, authority)

answer_seven()
# Out:
# (0.0003243556140278736, 0.003918957644934252)

# %%
ans_seven = answer_seven()
assert type(ans_seven) == tuple, "You must return a tuple"

# %% [markdown]
# ### Question 8
#
# Apply the HITS Algorithm to this network to find the 5 nodes with highest hub scores.
#
# *This function should return a list of the top 5 blogs in desending order of hub scores.*

# %%
def answer_eight():
    
    hub_sc = nx.hits(G2)[0]
    
    sorted_hub_sc = sorted(hub_sc, key=lambda x: hub_sc[x], reverse=True)
    
    return sorted_hub_sc[0:5]

answer_eight()
# Out:
# ['politicalstrategy.org',
#  'madkane.com/notable.html',
#  'liberaloasis.com',
#  'stagefour.typepad.com/commonprejudice',
#  'bodyandsoul.typepad.com']

# %%
ans_eight = answer_eight()
assert type(ans_eight) == list, "You must return a list"

# %% [markdown]
# ### Question 9
#
# Apply the HITS Algorithm to this network to find the 5 nodes with highest authority scores.
#
# *This function should return a list of the top 5 blogs in desending order of authority scores.*

# %%
def answer_nine():
    
    aut_sc = nx.hits(G2)[1]
    
    sorted_aut_sc = sorted(aut_sc.keys(), key=lambda x: aut_sc[x], reverse=True)
    
    return sorted_aut_sc[0:5]

answer_nine()
# Out:
# ['dailykos.com',
#  'talkingpointsmemo.com',
#  'atrios.blogspot.com',
#  'washingtonmonthly.com',
#  'talkleft.com']

# %%
ans_nine = answer_nine()
assert type(ans_nine) == list, "You must return a list"
